# %% [markdown]
# # NFL Fantasy dev

# %%
import nflreadpy as nfl

# Load current season play-by-play data
pbp = nfl.load_pbp()

# %%
pbp.shape
# Out:
# (25714, 372)

# %%
player_stats = nfl.load_player_stats([2022, 2023, 2024, 2025])
player_stats.head()
# Out:
# shape: (5, 114)
# ┌───────────┬───────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ player_id ┆ player_na ┆ player_di ┆ position ┆ … ┆ gwfg_bloc ┆ gwfg_dist ┆ fantasy_p ┆ fantasy_p │
# │ ---       ┆ me        ┆ splay_nam ┆ ---      ┆   ┆ ked       ┆ ance      ┆ oints     ┆ oints_ppr │
# │ str       ┆ ---       ┆ e         ┆ str      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆ str       ┆ ---       ┆          ┆   ┆ i32       ┆ i32       ┆ f64       ┆ f64       │
# │           ┆           ┆ str       ┆          ┆   ┆           ┆           ┆           ┆           │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 00-001959 ┆ T.Brady   ┆ Tom Brady ┆ QB       ┆ … ┆ 0         ┆ 0         ┆ 10.38     ┆ 10.38     │
# │ 6         ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-002282 ┆ A.Lee     ┆ Andy Lee  ┆ P        ┆ … ┆ 0         ┆ 0         ┆ 0.0       ┆ 0.0       │
# │ 4         ┆           ┆           ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-002325 ┆ R.Gould   ┆ Robbie    ┆ K        ┆ … ┆ 0         ┆ 0         ┆ 0.0       ┆ 0.0       │
# │ 2         ┆           ┆ Gould     ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-002345 ┆ A.Rodgers ┆ Aaron     ┆ QB       ┆ … ┆ 0         ┆ 0         ┆ 3.7       ┆ 3.7       │
# │ 9         ┆           ┆ Rodgers   ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-002385 ┆ M.Prater  ┆ Matt      ┆ K        ┆ … ┆ 0         ┆ 0         ┆ 0.0       ┆ 0.0       │
# │ 3         ┆           ┆ Prater    ┆          ┆   ┆           ┆           ┆           ┆           │
# └───────────┴───────────┴───────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
import polars as pl
MC_stats = player_stats.filter(
    pl.col("player_display_name") == "Christian McCaffrey"
)

# %%
MC_stats
# Out:
# shape: (53, 114)
# ┌───────────┬───────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ player_id ┆ player_na ┆ player_di ┆ position ┆ … ┆ gwfg_bloc ┆ gwfg_dist ┆ fantasy_p ┆ fantasy_p │
# │ ---       ┆ me        ┆ splay_nam ┆ ---      ┆   ┆ ked       ┆ ance      ┆ oints     ┆ oints_ppr │
# │ str       ┆ ---       ┆ e         ┆ str      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆ str       ┆ ---       ┆          ┆   ┆ i32       ┆ i32       ┆ f64       ┆ f64       │
# │           ┆           ┆ str       ┆          ┆   ┆           ┆           ┆           ┆           │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 11.7      ┆ 15.7      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 12.8      ┆ 16.8      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 11.5      ┆ 13.5      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 16.8      ┆ 25.8      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 16.4      ┆ 23.4      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ …         ┆ …         ┆ …         ┆ …        ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 17.1      ┆ 24.1      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 32.1      ┆ 39.1      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 6.8       ┆ 9.8       │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 29.3      ┆ 34.3      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 9.6       ┆ 17.6      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# └───────────┴───────────┴───────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
MC_stats_clean = MC_stats.select([
    col_name
    for col_name in MC_stats.columns
    if not MC_stats[col_name].is_null().all()
])

# %%
MC_stats_clean
# Out:
# shape: (53, 108)
# ┌───────────┬───────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ player_id ┆ player_na ┆ player_di ┆ position ┆ … ┆ gwfg_bloc ┆ gwfg_dist ┆ fantasy_p ┆ fantasy_p │
# │ ---       ┆ me        ┆ splay_nam ┆ ---      ┆   ┆ ked       ┆ ance      ┆ oints     ┆ oints_ppr │
# │ str       ┆ ---       ┆ e         ┆ str      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆ str       ┆ ---       ┆          ┆   ┆ i32       ┆ i32       ┆ f64       ┆ f64       │
# │           ┆           ┆ str       ┆          ┆   ┆           ┆           ┆           ┆           │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 11.7      ┆ 15.7      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 12.8      ┆ 16.8      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 11.5      ┆ 13.5      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 16.8      ┆ 25.8      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 16.4      ┆ 23.4      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ …         ┆ …         ┆ …         ┆ …        ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 17.1      ┆ 24.1      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 32.1      ┆ 39.1      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 6.8       ┆ 9.8       │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 29.3      ┆ 34.3      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 9.6       ┆ 17.6      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# └───────────┴───────────┴───────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
MC_stats_clean_final = MC_stats_clean.select([
    col_name
    for col_name in MC_stats_clean.columns
    if MC_stats_clean[col_name].mean() != 0
])

# %%
MC_stats_clean_final
# Out:
# shape: (53, 50)
# ┌───────────┬───────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ player_id ┆ player_na ┆ player_di ┆ position ┆ … ┆ penalties ┆ penalty_y ┆ fantasy_p ┆ fantasy_p │
# │ ---       ┆ me        ┆ splay_nam ┆ ---      ┆   ┆ ---       ┆ ards      ┆ oints     ┆ oints_ppr │
# │ str       ┆ ---       ┆ e         ┆ str      ┆   ┆ i32       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆ str       ┆ ---       ┆          ┆   ┆           ┆ i32       ┆ f64       ┆ f64       │
# │           ┆           ┆ str       ┆          ┆   ┆           ┆           ┆           ┆           │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 11.7      ┆ 15.7      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 12.8      ┆ 16.8      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 11.5      ┆ 13.5      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 16.8      ┆ 25.8      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 16.4      ┆ 23.4      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ …         ┆ …         ┆ …         ┆ …        ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 17.1      ┆ 24.1      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 32.1      ┆ 39.1      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 6.8       ┆ 9.8       │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 29.3      ┆ 34.3      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 00-003328 ┆ C.McCaffr ┆ Christian ┆ RB       ┆ … ┆ 0         ┆ 0         ┆ 9.6       ┆ 17.6      │
# │ 0         ┆ ey        ┆ McCaffrey ┆          ┆   ┆           ┆           ┆           ┆           │
# └───────────┴───────────┴───────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/aveleyra/miniconda3/lib/python3.13/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/aveleyra/miniconda3/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/aveleyra/miniconda3/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aveleyra/miniconda3/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/aveleyra/miniconda3/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /home/aveleyra/miniconda3/lib/python3.13/site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in /home/aveleyra/miniconda3/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/aveleyra/miniconda3/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/aveleyra/miniconda3/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/aveleyra/miniconda3/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/aveleyra/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt


# --- 3. Convertir season y week a enteros y crear columna "season_week" ---
df = MC_stats_clean_final.with_columns([
    pl.col("season").cast(pl.Int32),
    pl.col("week").cast(pl.Int32),
    (pl.col("season").cast(pl.Utf8) + "-W" + pl.col("week").cast(pl.Utf8)).alias("season_week")
])

# --- 4. Ordenar cronológicamente ---
df = df.sort(["season", "week"])

# --- 5. Convertir a pandas para graficar ---
df_pd = df.to_pandas()

# --- 6. Graficar ---
plt.figure(figsize=(12, 6))
plt.plot(df_pd["season_week"], df_pd["rushing_yards"], marker="o", linestyle="-")
plt.title("Rushing Yards Over Time")
plt.xlabel("Season - Week")
plt.ylabel("Rushing Yards")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
